# %%
import os
import pandas as pd
from copy import copy

# Set up the directories
code_dir = os.getcwd()
project_dir = os.path.dirname(code_dir)
data_dir = os.path.join(project_dir, 'data')

raw_data_dir = os.path.join(data_dir, 'raw_data')
ad_hoc_data_dir = os.path.join(data_dir, 'ad_hoc_data')
processed_data_dir = os.path.join(data_dir, 'processed_data')

# Load the data
# Load add-hoc food items data (data containing food matches between differnet databases)
food_items = pd.read_excel(os.path.join(ad_hoc_data_dir, 'food_items.xlsx'))
food_items['food_id'] = food_items['CSES_food_item']
food_items.drop(['Comments 1', 'Comments 2'], axis=1, inplace=True)

# Load add-hoc nutrient data (data containing nutrient matches between different databases and information about lower and upper limits)
nutrient_match = pd.read_excel(os.path.join(ad_hoc_data_dir, 'nutrient_match.xlsx'))
nutrient_list = nutrient_match['nutrient'].to_list()

# Read food composition data (Excel 6. Food composition)
food_composition_raw = pd.read_excel(os.path.join(raw_data_dir, '6.food_composition.xlsx'), sheet_name='6.food_composition', header=0)
food_items_enhance_id = food_items['ENHANCE_ID'].to_list()

# ---------------------------------------------------------------------------------------------------------------------
# Build food_items_nutritional dataframe
# Columns: food_id, ENHANCE_ID, EDIBLE, nutrients (from nutrient_match)
# Stored: food_items_nutritional.xlsx in processed_data_dir
# ---------------------------------------------------------------------------------------------------------------------

# Filter the food composition data to include only the food items (rows) with ENHANCE_IDs present in food_items
# Select the nutrients (columns) for ENHANCE_ID and the nutrients listed in nutrient_match (with nutrient_name_food_composition label)
food_composition_filtered = food_composition_raw[
    food_composition_raw['ENHANCE_ID'].isin(food_items_enhance_id)
][['ENHANCE_ID', 'EDIBLE'] + nutrient_match['nutrient_name_food_composition'].tolist()]

# Replace 'nutrient_name_food_composition' names with 'nutrient' names in nutrient_match
food_composition_filtered.columns = ['ENHANCE_ID', 'EDIBLE'] + nutrient_list
# Add food_id column to the final food_items_nutritional dataframe
food_items_nutritional = food_items.loc[:,['food_id', 'ENHANCE_ID']].merge(food_composition_filtered, on='ENHANCE_ID', how='left')
# Save the food_items_nutritional dataframe to an Excel file
food_items_nutritional.to_excel(os.path.join(processed_data_dir, 'food_items_nutritional.xlsx'), index=False)

# ---------------------------------------------------------------------------------------------------------------------
# Build 
# Columns: 
# Stored: 
# ---------------------------------------------------------------------------------------------------------------------
# Out:
#                                           food_id ENHANCE_ID  EDIBLE  \
# 0                                            Eggs      13726    0.87
# 1                                         Mudfish      14121    0.77
# 2                                         Catfish     103879    0.52
# 3                               Shrimp or lobster      54233    1.00
# 4                     Processed or preserved fish      53801    1.00
# 5                                          Banana      44288    0.69
# 6                                           Mango      44493    0.70
# 7                                          Papaya      14540    0.75
# 8                                 Rice, quality 1     104945    1.00
# 9                                    Rice noodles      94879    1.00
# 10                                  Khmer noodles      94850    1.00
# 11                                 Nuts and seeds      55519    1.00
# 12             Peas, beans, soybean, bean sprouts      15557    1.00
# 13             Peas, beans, soybean, bean sprouts      65322    1.00
# 14             Peas, beans, soybean, bean sprouts      96689    0.83
# 15                                           Pork      96004    0.69
# 16                                           Beef      15650    1.00
# 17                                           Duck      15823    0.84
# 18                                        Chicken      55774    0.74
# 19                                 Milk or yogurt      76198    1.00
# 20                                 Milk or yogurt      26236    1.00
# 21                                    Oil or fats      96320    1.00
# 22  Tubers (potato, sweet potato, carrot, radish)      16446    0.84
# 23  Tubers (potato, sweet potato, carrot, radish)      56746    0.86
# 24  Tubers (potato, sweet potato, carrot, radish)      57173    0.99
# 25                        Sugarcane or palm sugar      56571    1.00
# 26              Trakun (watercress marsh cabbage)      17258    0.71
# 27                  Spring onion, garlic, leeks,       17114    0.87
# 28                                 Cabbage leaves      56716    0.84
# 29             Gourd, cucumber, pumpkin, eggplant      56839    0.87
# 30             Gourd, cucumber, pumpkin, eggplant      56787    0.95
# 31             Gourd, cucumber, pumpkin, eggplant      17166    0.79
# 32             Gourd, cucumber, pumpkin, eggplant      96797    0.81
# 33                    Mushrooms (dried and fresh)      97083    1.00
# 34                    Mushrooms (dried and fresh)      97084    1.00
#
#     Energy (kcal)  Protein (g)     Fat (g)     Ca (mg)  FolicAcid (Âug DFE)  \
# 0           139.0    14.489000    9.000000         NaN                 50.0
# 1           101.0    17.742500    3.300000  103.820000                  NaN
# 2           117.0    16.330000    5.700000   38.000000                  8.0
# 3            79.0    16.700000    0.900000   31.000000                  3.0
# 4           105.0    18.500000    2.900000   12.000000                 10.0
# 5            92.0     1.000000    0.500000    6.000000                 19.0
# 6            65.0     0.500000    0.300000   10.000000                 14.0
# 7            33.0     0.610000    0.146667   28.682000                  NaN
# 8           353.0     6.141215    0.462644   10.838122                 20.0
# 9           108.0     1.790000    0.200000    4.000000                  1.0
# 10          384.0    14.160000    4.440000   35.000000                230.0
# 11          567.0    25.800000   49.200000   92.000000                126.0
# 12          424.0    32.936803   19.940000  240.565000                100.0
# 13          326.0    22.400000    1.300000   72.000000                334.0
# 14           47.0     2.800000    0.400000   50.000000                 62.0
# 15          211.0    18.220000   14.790000   11.000000                  3.0
# 16          103.0    20.742500    2.255000    4.259231                  7.0
# 17          130.0    21.600000    4.800000    4.000000                 25.0
# 18          285.0    26.900000   18.900000   13.000000                  5.0
# 19           66.0     3.200000    3.900000  115.000000                  6.0
# 20          117.0     7.000000    6.500000  268.000000                 14.0
# 21          862.0     0.000000  100.000000    0.000000                  0.0
# 22           98.0     0.615000    0.260000   24.500000                 11.0
# 23           45.0     1.100000    0.200000   31.000000                 14.0
# 24           13.0     0.700000    0.100000   14.000000                 13.0
# 25          369.0     0.600000    0.000000  377.000000                  1.0
# 26           43.0     1.921667    0.384000  107.000000                 57.0
# 27           59.0     1.375000    0.074000   23.969000                 19.0
# 28           15.0     2.300000    0.200000   74.000000                 73.0
# 29           20.0     0.900000    0.300000   27.000000                 20.0
# 30           13.0     0.700000    0.100000   14.000000                 13.0
# 31           18.0     1.400000    0.300000   51.820000                 16.0
# 32           25.0     0.980000    0.180000    9.000000                 22.0
# 33          296.0     9.580000    0.990000   11.000000                163.0
# 34           34.0     2.240000    0.490000    2.000000                 13.0
#
#     Iron Absorbed (mg)  Iron (mg)  Magnesium (mg)  Niacin (mg NE)  \
# 0             0.385000   1.540000          20.880        3.400000
# 1             0.260313   1.041250          42.650        8.026844
# 2             0.225000   0.900000          30.000        1.400000
# 3             0.625000   2.500000          27.000        5.983333
# 4             0.100000   0.400000          28.000        5.850000
# 5             0.015000   0.300000          29.000        0.700000
# 6             0.005000   0.100000           9.000        0.733333
# 7             0.017435   0.348695          10.310        0.488000
# 8             0.036510   0.730194          35.000        0.423106
# 9             0.007000   0.140000           3.000        0.072000
# 10            0.200500   4.010000          58.000        8.387000
# 11            0.230000   4.600000         168.000       18.466667
# 12            0.567000  11.340000         207.000        7.900000
# 13            0.375000   7.500000         116.000        5.916667
# 14            0.023500   0.470000          44.000        0.410000
# 15            0.222500   0.890000          21.000        4.730000
# 16            0.494615   1.978462          15.310        9.270000
# 17            0.600000   2.400000          19.000        1.200000
# 18            0.350000   1.400000          20.000       10.816667
# 19            0.011750   0.100000          11.000        0.866667
# 20            0.023500   0.200000          26.000        1.316667
# 21            0.000000   0.000000           0.000        0.000000
# 22            0.075750   1.515000          25.000        0.800000
# 23            0.030000   0.600000          13.000        0.700000
# 24            0.015000   0.300000          11.000        0.283333
# 25            0.090000   1.800000          22.000        0.200000
# 26            0.109880   2.197597          19.420        0.900000
# 27            0.047081   0.941618          24.121        0.346000
# 28            0.055000   1.100000          15.000        0.816667
# 29            0.020000   0.400000          24.000        0.633333
# 30            0.015000   0.300000          11.000        0.283333
# 31            0.035000   0.700000          10.000        0.800000
# 32            0.011500   0.230000          14.000        0.649000
# 33            0.086000   1.720000         132.000       14.100000
# 34            0.020500   0.410000          20.000        3.877000
#
#     PantothenicAcid (mg)  Vitamin A (Âug RE)  Vitamin B1 (mg)  \
# 0               1.396455          165.246000         0.184000
# 1               0.602328                 NaN         0.040000
# 2               0.602328           25.000000         0.120000
# 3               0.800000           51.000000         0.020000
# 4               0.910000           15.000000         0.230000
# 5               0.260000            4.000000         0.050000
# 6               0.160000          200.000000         0.060000
# 7               0.178481           60.105833         0.080000
# 8               1.080266            0.000000         0.072783
# 9               0.011000            0.000000         0.018000
# 10              0.912000           17.000000         1.133000
# 11              1.390000            0.000000         0.250000
# 12              0.502999            1.083333         0.730000
# 13              0.570000            0.000000         0.410000
# 14              0.055000           43.000000         0.107000
# 15              0.899000            1.000000         0.622000
# 16              0.551862            0.000000         0.060000
# 17              0.747392           24.000000         0.360000
# 18              0.750000           39.000000         0.090000
# 19              0.350000           55.000000         0.040000
# 20              0.820000           49.000000         0.070000
# 21              0.000000            0.000000         0.000000
# 22              0.370598            1.416667         0.078000
# 23              0.300000          971.000000         0.030000
# 24              0.180000           10.500000         0.020000
# 25              0.110000            0.000000         0.010000
# 26              0.162250          198.640000         0.140000
# 27              0.445145            1.898000         0.045000
# 28              0.020000          151.500000         0.040000
# 29              0.140000           14.500000         0.040000
# 30              0.180000           10.500000         0.020000
# 31              0.288537          369.166667         0.070000
# 32              0.281000            1.000000         0.039000
# 33             21.879000            0.000000         0.300000
# 34              1.500000            0.000000         0.015000
#
#     Vitamin B2 (mg)  Vitamin B6 (mg)  Vitamin B12(Âug)  Vitamin C (mg)  \
# 0          0.400000         0.149231          2.587273             NaN
# 1          0.050000         0.241643          3.415777          0.0000
# 2          0.060000         0.290000          2.300000          0.0000
# 3          0.020000         0.100000          1.190000          2.0000
# 4          0.070000         0.110000          2.900000          1.0000
# 5          0.100000         0.580000          0.000000          9.0000
# 6          0.060000         0.130000          0.000000         36.0000
# 7          0.030000              NaN          0.000000         61.8000
# 8          0.027146         0.125000          0.000000          0.0000
# 9          0.004000         0.006000          0.000000          0.0000
# 10         0.426000         0.216000          0.290000          0.0000
# 11         0.110000         0.260000          0.000000          0.0000
# 12         0.500000         0.417000          0.000000          0.0000
# 13         0.150000         0.310000          0.000000          3.0000
# 14         0.110000         0.024000          0.000000         18.8000
# 15         0.255000         0.504000          0.670000          0.3000
# 16         0.190000         0.320000          1.977236          1.3000
# 17         0.450000         0.340000          1.878980         17.9000
# 18         0.240000         0.250000          0.230000          0.0000
# 19         0.170000         0.060000          0.400000          1.0000
# 20         0.300000         0.070000          0.820000          3.0000
# 21         0.000000         0.000000          0.000000          0.0000
# 22         0.061000         0.209000          0.000000         20.2660
# 23         0.060000         0.250000          0.000000          2.0000
# 24         0.020000         0.040000          0.000000          5.0000
# 25         0.010000         0.030000          0.000000          0.0000
# 26         0.400000         0.096000          0.000000         30.3925
# 27         0.136000         0.168068          0.000000          4.5000
# 28         0.060000         0.110000          0.000000         25.0000
# 29         0.040000         0.070000          0.000000          6.0000
# 30         0.020000         0.040000          0.000000          5.0000
# 31         0.060000         0.061000          0.000000         21.0550
# 32         0.037000         0.084000          0.000000          2.2000
# 33         1.270000         0.965000          0.000000          3.5000
# 34         0.217000         0.293000          0.000000          0.0000
#
#     Zinc (mg)
# 0    2.355250
# 1    0.305714
# 2    0.600000
# 3    1.300000
# 4    0.600000
# 5    0.200000
# 6    0.000000
# 7    0.174000
# 8    1.100000
# 9    0.250000
# 10   1.920000
# 11   3.300000
# 12   5.700000
# 13   2.800000
# 14   0.370000
# 15   2.270000
# 16   3.518182
# 17   1.900000
# 18   1.800000
# 19   0.400000
# 20   1.200000
# 21   0.000000
# 22   0.383067
# 23   0.300000
# 24   0.200000
# 25   0.300000
# 26   0.510530
# 27   0.410000
# 28   0.200000
# 29   0.400000
# 30   0.200000
# 31   0.106750
# 32   0.160000
# 33   7.660000
# 34   1.030000

# %%
display(food_items.loc[:,'ENHANCE_ID'])
# Out:
# food_id
# Eggs                                              13726
# Mudfish                                           14121
# Catfish                                          103879
# Shrimp or lobster                                 54233
# Processed or preserved fish                       53801
# Banana                                            44288
# Mango                                             44493
# Papaya                                            14540
# Rice, quality 1                                  104945
# Rice noodles                                      94879
# Khmer noodles                                     94850
# Nuts and seeds                                    55519
# Peas, beans, soybean, bean sprouts                15557
# Peas, beans, soybean, bean sprouts                65322
# Peas, beans, soybean, bean sprouts                96689
# Pork                                              96004
# Beef                                              15650
# Duck                                              15823
# Chicken                                           55774
# Milk or yogurt                                    76198
# Milk or yogurt                                    26236
# Oil or fats                                       96320
# Tubers (potato, sweet potato, carrot, radish)     16446
# Tubers (potato, sweet potato, carrot, radish)     56746
# Tubers (potato, sweet potato, carrot, radish)     57173
# Sugarcane or palm sugar                           56571
# Trakun (watercress marsh cabbage)                 17258
# Spring onion, garlic, leeks,                      17114
# Cabbage leaves                                    56716
# Gourd, cucumber, pumpkin, eggplant                56839
# Gourd, cucumber, pumpkin, eggplant                56787
# Gourd, cucumber, pumpkin, eggplant                17166
# Gourd, cucumber, pumpkin, eggplant                96797
# Mushrooms (dried and fresh)                       97083
# Mushrooms (dried and fresh)                       97084
# Name: ENHANCE_ID, dtype: int64

# %%
display(food_composition_raw.head())
# Out:
#   ENHANCE_ID  original_food_Code  FCT_ID     FCT_name  \
# 0      15227                5227       1  Bangladesh
# 1      14524                4524       1  Bangladesh
# 2      16819                6819       1  Bangladesh
# 3      14515                4515       1  Bangladesh
# 4      17246                7246       1  Bangladesh
#
#                              food_name_english food_name_other  \
# 0                                         Salt           Lobon
# 1               Orange juice, raw, unsweetened    Komolar ross
# 2                              Gourd, ash, raw       Chalkumra
# 3  Muskmelon, bangee, light orange flesh, ripe    Bangee, paka
# 4                       Tomato, red, ripe, raw    Paka tomato
#
#       food_name_scientific food_name_generic  FG1   FG2  ...  FECOE     FEABS  \
# 0                      NaN              Salt   74  79.0  ...   0.05  0.000000
# 1        Citrus reticulata            Orange   63  64.0  ...   0.05  0.035000
# 2        Benincasa hispida             Gourd   58  62.0  ...   0.05  0.040000
# 3             Cucumis melo         Muskmelon   63  64.0  ...   0.05  0.000000
# 4  Lycopersicon esculentum            Tomato   63  65.0  ...   0.05  0.009861
#
#    FECOECAT     P       K  MN         MG  SE     SODIUM    ZN
# 0       3.0   0.0    0.00 NaN   0.000000 NaN  39340.000  0.00
# 1       3.0  13.0  150.00 NaN   8.000000 NaN     10.000  0.05
# 2       3.0  14.0  139.00 NaN  17.423265 NaN     38.780  0.10
# 3       3.0  35.0  130.00 NaN  20.000000 NaN      7.000  0.06
# 4       3.0  24.0  156.31 NaN   7.418000 NaN      6.797  0.41
#
# [5 rows x 52 columns]
